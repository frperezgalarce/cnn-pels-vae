# %%
import pandas as pd

# %%
df = pd.read_csv('sn_ratio_sample.csv', index_col=0)

# %%
df.quantile([i/200 for i in range(200)]).plot(xlabel='quantile', ylabel='SNR')
# Out:
# <AxesSubplot:xlabel='quantile', ylabel='SNR'>

# %%
df.quantile([i/200 for i in range(10)]).plot(xlabel='quantile', ylabel='SNR')
# Out:
# <AxesSubplot:xlabel='quantile', ylabel='SNR'>

# %%
df.mean()
# Out:
# 0    33.772385
# dtype: float64

# %%
df.quantile([i/200 for i in range(25)])
# Out:
#               0
# 0.000  1.888987
# 0.005  4.992279
# 0.010  5.616503
# 0.015  6.000000
# 0.020  6.384672
# 0.025  6.684885
# 0.030  6.925481
# 0.035  7.108163
# 0.040  7.276353
# 0.045  7.432194
# 0.050  7.564424
# 0.055  7.693118
# 0.060  7.816111
# 0.065  7.937199
# 0.070  8.020540
# 0.075  8.119364
# 0.080  8.226386
# 0.085  8.318965
# 0.090  8.413124
# 0.095  8.500000
# 0.100  8.600036
# 0.105  8.687764
# 0.110  8.764330
# 0.115  8.839266
# 0.120  8.930039
