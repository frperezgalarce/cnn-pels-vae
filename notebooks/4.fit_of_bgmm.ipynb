# %%
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.mixture import BayesianGaussianMixture
from typing import Optional, Dict, Union, Tuple, ClassVar, Any
import os
from sklearn.neighbors import NearestNeighbors
import yaml
from itertools import combinations

new_directory = '/home/franciscoperez/Documents/GitHub/CNN-PELSVAE2/cnn-pels-vae/'
os.chdir(new_directory)
from src.utils import load_yaml_priors, extract_midpoints, extract_maximum_of_max_periods

import warnings
warnings.filterwarnings('ignore')

with open('src/configuration/paths.yaml', 'r') as file:
    YAML_FILE: str = yaml.safe_load(file)

PATHS: str = YAML_FILE['paths']
PATH_PRIOS: str = PATHS['PATH_PRIOS']
PATH_PP: str = PATHS['PATH_PP']
PATH_FIGURES: str = PATHS['PATH_FIGURES']


with open('src/configuration/regressor.yaml', 'r') as file:
    config_file: Dict[str, Any] = yaml.safe_load(file)

sufix_path: str = config_file['model_parameters']['sufix_path']

columns = ['Type','Period', 'teff_val', '[Fe/H]_J95', 'abs_Gmag', 'radius_val', 'logg']

class BayesianGaussianMixtureModel:
    def __init__(self, n_components: int = 2, random_state: Optional[int] = None, 
                covariance_type = 'full', max_iter = 5000, mean_prior=None):
        self.n_components = n_components
        self.random_state = random_state
        self.covariance_type = covariance_type
        self.max_iter = max_iter
        self.object = None
        self.mean_prior = mean_prior
        self.bgm = BayesianGaussianMixture(n_components=self.n_components, 
                                            random_state=self.random_state, 
                                            covariance_type=self.covariance_type, 
                                            max_iter = self.max_iter, 
                                            mean_prior = self.mean_prior)

    def train(self, X: pd.DataFrame) -> None:
        self.bgm.fit(X)
        self.object = self.bgm  # Saving the trained model as the object attribute
        np.set_printoptions(precision=4, suppress=True)

        print("Hyperparameters:")
        print(self.bgm)  # This prints the hyperparameters

        print("\nFitted Means:")
        print(self.bgm.means_)

        print("\nFitted Covariances:")
        print(self.bgm.covariances_)


    def save_model(self, filename: str) -> None:
        with open(filename, 'wb') as file:
            pickle.dump({
                'n_components': self.n_components,
                'random_state': self.random_state,
                'mean_prior': self.mean_prior,
                'model': self.bgm
            }, file)

    @classmethod
    def load_model(cls, filename: str) -> "BayesianGaussianMixtureModel":
        with open(filename, 'rb') as file:
            model_data: Dict = pickle.load(file)
        instance = cls(n_components=model_data['n_components'], random_state=model_data['random_state'])
        instance.mean_prior = model_data['mean_prior']
        instance.bgm = model_data['model']
        instance.object = instance.bgm  # Save the loaded model as the object attribute
        return instance

    def generate_samples(self, n_samples: int = 1) -> np.array:
        samples, _ = self.bgm.sample(n_samples)
        return samples

def train_and_save(priors: bool = True, 
                   columns=['Type','Period', 'teff_val', '[Fe/H]_J95', 'abs_Gmag', 'radius_val', 'logg']) -> None:
    
    data = pd.read_csv(PATH_PP)
    df_selected_columns = data[columns]
    classes = df_selected_columns.Type.unique()
    columns.remove('Type')

    mean_prior_dict = load_yaml_priors(PATH_PRIOS)

    for star_class in classes:
        print(star_class)
        star_type_data = mean_prior_dict['StarTypes'][star_class]
        components = len([key for key in star_type_data.keys()])-3
        df_filtered_by_class = df_selected_columns[df_selected_columns.Type==star_class]
        X = df_filtered_by_class[columns]
        X = X.dropna()
        if 'LOG' in sufix_path:
            X['Period']=np.log(X['Period']) 
            X['teff_val']=np.log(X['teff_val']) 
            X['radius_val']=np.log(X['radius_val']) 
            period_upper_limit = np.log(mean_prior_dict['StarTypes'][star_class]['max_period'])
            period_lower_limit = np.log(mean_prior_dict['StarTypes'][star_class]['min_period'])
        else: 
            period_upper_limit = mean_prior_dict['StarTypes'][star_class]['max_period']
            period_lower_limit = mean_prior_dict['StarTypes'][star_class]['min_period']
        X = X[X.Period<period_upper_limit]
        X = X[X.Period>period_lower_limit]

        if X.shape[0] > 30:
            
            if priors:
                try:
                    print(mean_prior_dict['StarTypes'][star_class])
                    array_midpoints = extract_midpoints(mean_prior_dict['StarTypes'][star_class])
                    array_midpoints = np.array(array_midpoints)
                    if 'LOG' in sufix_path: 
                        array_midpoints[:, [0, 1, 4]] = np.log(array_midpoints[:, [0, 1, 4]])
                    print(array_midpoints)

                    print(components)
                    bgmm = BayesianGaussianMixtureModel(n_components=components, random_state=42, mean_prior=np.mean(array_midpoints, axis=0))
                    print(bgmm)
                    bgmm.train(X)
                except Exception as error:
                    raise('The model was not trained')
            else:
                bgmm = BayesianGaussianMixtureModel(n_components=components, random_state=42, mean_prior=None)
                bgmm.train(X)

            bgmm.save_model('models/bgm_model_'+str(star_class)+'_priors_'+str(priors)+'_PP_'+str(len(columns))+'.pkl')
# Out:
# GAIA3_LOG_6PP

# %%
train_and_save(priors = True, columns= columns)
# Out:
# ACEP
# {'CompleteName': 'Anomalous Cepheids', 'max_period': 2.5, 'min_period': 0.3, 'Binary': {'Period': [1, 10], 'teff_val': [5000, 6000], 'FeH_J95': [-0.1, 0.1], 'abs_Gmag': [0.5, 2.0], 'radius_val': [0.8, 1.5], 'logg': [3.5, 4.5], 'Midpoints': {'Period': 5.5, 'teff_val': 5500, 'FeH_J95': 0.0, 'abs_Gmag': 1.25, 'radius_val': 1.15, 'logg': 4}}, 'Ternary': {'Period': [5, 20], 'teff_val': [4500, 5600], 'FeH_J95': [-0.2, 0.2], 'abs_Gmag': [0.7, 2.5], 'radius_val': [1, 2], 'logg': [3, 4], 'Midpoints': {'Period': 12.5, 'teff_val': 5050, 'FeH_J95': 0.0, 'abs_Gmag': 1.6, 'radius_val': 1.5, 'logg': 3.5}}, 'Pulsating': {'Period': [0.5, 8], 'teff_val': [5200, 5800], 'FeH_J95': [-0.1, 0.1], 'abs_Gmag': [0.6, 1.8], 'radius_val': [0.9, 1.4], 'logg': [3.8, 4.2], 'Midpoints': {'Period': 4.25, 'teff_val': 5500, 'FeH_J95': 0.0, 'abs_Gmag': 1.2, 'radius_val': 1.15, 'logg': 4}}}
# [[1.70474809 8.61250337 0.         1.25       0.13976194 4.        ]
#  [2.52572864 8.52714352 0.         1.6        0.40546511 3.5       ]
#  [1.44691898 8.61250337 0.         1.2        0.13976194 4.        ]]
# 3
# <__main__.BayesianGaussianMixtureModel object at 0x7fc204875910>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([1.8925, 8.5841, 0.    , 1.35  , 0.2283, 3.8333]),
#                         n_components=3, random_state=42)
#
# Fitted Means:
# [[ 0.0508  8.694  -3.3924  5.5225 -0.413   4.6499]
#  [-0.01    8.7133 -1.5583  5.1785 -0.315   4.611 ]
#  [-0.106   8.8309 -2.1181  4.0961 -0.0387  4.422 ]]
#
# Fitted Covariances:
# [[[ 0.0911 -0.0079 -0.0348  0.0452 -0.0061 -0.0023]
#   [-0.0079  0.003   0.0096 -0.0228  0.0046 -0.0017]
#   [-0.0348  0.0096  0.4804 -0.0885  0.0174 -0.0087]
#   [ 0.0452 -0.0228 -0.0885  0.1886 -0.0399  0.0188]
#   [-0.0061  0.0046  0.0174 -0.0399  0.009  -0.0049]
#   [-0.0023 -0.0017 -0.0087  0.0188 -0.0049  0.0035]]
#
#  [[ 0.4298 -0.0026 -0.2517 -0.0469  0.0221 -0.0237]
#   [-0.0026  0.001  -0.0065 -0.004   0.0005  0.0002]
#   [-0.2517 -0.0065  0.2696  0.0462 -0.0179  0.0147]
#   [-0.0469 -0.004   0.0462  0.1138 -0.0317  0.0254]
#   [ 0.0221  0.0005 -0.0179 -0.0317  0.0117 -0.0094]
#   [-0.0237  0.0002  0.0147  0.0254 -0.0094  0.0082]]
#
#  [[ 0.4142 -0.0043  0.1116 -0.0696  0.0326 -0.0362]
#   [-0.0043  0.0014 -0.0126 -0.0143  0.0046 -0.0032]
#   [ 0.1116 -0.0126  0.7064  0.1404 -0.0518  0.0554]
#   [-0.0696 -0.0143  0.1404  0.2426 -0.0741  0.0625]
#   [ 0.0326  0.0046 -0.0518 -0.0741  0.0243 -0.0207]
#   [-0.0362 -0.0032  0.0554  0.0625 -0.0207  0.0188]]]
# CEP
# {'CompleteName': 'Classical Cepheids', 'max_period': 200, 'min_period': 1, 'Fundamental': {'Period': [1, 200], 'teff_val': [5000, 8000], 'FeH_J95': [-0.3, 0.3], 'abs_Gmag': [-2, 2], 'radius_val': [20, 60], 'logg': [0.5, 2.0], 'Midpoints': {'Period': 100.5, 'teff_val': 6500, 'FeH_J95': 0, 'abs_Gmag': 0, 'radius_val': 40, 'logg': 1.25}}, 'First-overtone': {'Period': [1, 5], 'teff_val': [5200, 7800], 'FeH_J95': [-0.25, 0.25], 'abs_Gmag': [-1, 1], 'radius_val': [18, 55], 'logg': [0.7, 1.9], 'Midpoints': {'Period': 3, 'teff_val': 6500, 'FeH_J95': 0, 'abs_Gmag': 0, 'radius_val': 36.5, 'logg': 1.3}}, 'Second-overtone': {'Period': [5, 10], 'teff_val': [5400, 7700], 'FeH_J95': [-0.2, 0.2], 'abs_Gmag': [-1, 1], 'radius_val': [17, 50], 'logg': [0.8, 1.8], 'Midpoints': {'Period': 7.5, 'teff_val': 6550, 'FeH_J95': 0, 'abs_Gmag': 0, 'radius_val': 33.5, 'logg': 1.3}}, 'Multi-tone': {'Period': [1, 100], 'teff_val': [5300, 7900], 'FeH_J95': [-0.3, 0.3], 'abs_Gmag': [-2, 2], 'radius_val': [20, 60], 'logg': [0.5, 2.0], 'Midpoints': {'Period': 50.5, 'teff_val': 6600, 'FeH_J95': 0, 'abs_Gmag': 0, 'radius_val': 40, 'logg': 1.25}}}
# [[4.6102 8.7796 0.     0.     3.6889 1.25  ]
#  [1.0986 8.7796 0.     0.     3.5973 1.3   ]
#  [2.0149 8.7872 0.     0.     3.5115 1.3   ]
#  [3.922  8.7948 0.     0.     3.6889 1.25  ]]
# 4
# <__main__.BayesianGaussianMixtureModel object at 0x7fc29bb01c90>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([2.9114, 8.7853, 0.    , 0.    , 3.6217, 1.275 ]),
#                         n_components=4, random_state=42)
#
# Fitted Means:
# [[ 0.5993  8.665  -1.6403  4.9155 -0.0939  4.4338]
#  [ 1.0975  8.725  -0.7562  2.68    0.8022  3.7881]
#  [ 0.4876  8.6731 -3.7569  5.0842 -0.1665  4.4493]
#  [ 1.6353  8.8945 -0.8155  0.39    1.6778  3.2459]]
#
# Fitted Covariances:
# [[[ 0.1497 -0.0062  0.0749 -0.1741  0.0933 -0.0567]
#   [-0.0062  0.0031  0.0038 -0.0221  0.0039 -0.0022]
#   [ 0.0749  0.0038  0.5187 -0.2826  0.1165 -0.0633]
#   [-0.1741 -0.0221 -0.2826  0.7536 -0.3022  0.1805]
#   [ 0.0933  0.0039  0.1165 -0.3022  0.1327 -0.0803]
#   [-0.0567 -0.0022 -0.0633  0.1805 -0.0803  0.0496]]
#
#  [[ 0.2569 -0.0326  0.0554 -0.2374  0.1761 -0.1346]
#   [-0.0326  0.0109  0.0029 -0.0034 -0.0208  0.0223]
#   [ 0.0554  0.0029  0.283  -0.1695  0.0666 -0.0111]
#   [-0.2374 -0.0034 -0.1695  0.6987 -0.314   0.1862]
#   [ 0.1761 -0.0208  0.0666 -0.314   0.1876 -0.1327]
#   [-0.1346  0.0223 -0.0111  0.1862 -0.1327  0.1047]]
#
#  [[ 0.1075 -0.0071 -0.0098 -0.1074  0.0674 -0.0529]
#   [-0.0071  0.0054  0.0101 -0.0435  0.0095 -0.0056]
#   [-0.0098  0.0101  0.1284 -0.0928  0.0282 -0.0231]
#   [-0.1074 -0.0435 -0.0928  0.9938 -0.379   0.2768]
#   [ 0.0674  0.0095  0.0282 -0.379   0.1618 -0.1216]
#   [-0.0529 -0.0056 -0.0231  0.2768 -0.1216  0.0937]]
#
#  [[ 0.9995 -0.2373  0.1368 -0.4033  0.5822 -0.5209]
#   [-0.2373  0.1788  0.0554 -0.1183 -0.2179  0.2614]
#   [ 0.1368  0.0554  0.5053 -0.267   0.0504  0.0443]
#   [-0.4033 -0.1183 -0.267   1.7688 -0.6472  0.3254]
#   [ 0.5822 -0.2179  0.0504 -0.6472  0.6634 -0.5788]
#   [-0.5209  0.2614  0.0443  0.3254 -0.5788  0.5712]]]
# DSCT
# {'CompleteName': 'Delta Scuti Variables', 'max_period': 0.3, 'min_period': 0.02, 'Single-mode': {'Period': [0.02, 0.3], 'teff_val': [6500, 8500], 'FeH_J95': [-0.2, 0.2], 'abs_Gmag': [0.5, 4.0], 'radius_val': [1.5, 2.5], 'logg': [3.5, 4.5], 'Midpoints': {'Period': 0.16, 'teff_val': 7500, 'FeH_J95': 0, 'abs_Gmag': 2.25, 'radius_val': 2, 'logg': 4}}, 'Multi-mode': {'Period': [0.02, 0.3], 'teff_val': [6600, 8400], 'FeH_J95': [-0.15, 0.15], 'abs_Gmag': [0.6, 3.8], 'radius_val': [1.4, 2.4], 'logg': [3.6, 4.4], 'Midpoints': {'Period': 0.16, 'teff_val': 7500, 'FeH_J95': 0, 'abs_Gmag': 2.2, 'radius_val': 1.9, 'logg': 4}}}
# [[-1.8326  8.9227  0.      2.25    0.6931  4.    ]
#  [-1.8326  8.9227  0.      2.2     0.6419  4.    ]]
# 2
# <__main__.BayesianGaussianMixtureModel object at 0x7fc29bb017d0>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([-1.8326,  8.9227,  0.    ,  2.225 ,  0.6675,  4.    ]),
#                         n_components=2, random_state=42)
#
# Fitted Means:
# [[-2.0826  8.9587 -0.9818  1.806   0.7682  3.9445]
#  [-2.2531  8.6353 -2.3186  5.5617 -0.3134  4.5686]]
#
# Fitted Covariances:
# [[[ 0.1069  0.0044  0.0381 -0.0702  0.0261 -0.0141]
#   [ 0.0044  0.0159 -0.0269 -0.0123 -0.0188  0.0178]
#   [ 0.0381 -0.0269  0.4257 -0.2587  0.1559 -0.0872]
#   [-0.0702 -0.0123 -0.2587  1.417  -0.6328  0.4087]
#   [ 0.0261 -0.0188  0.1559 -0.6328  0.3212 -0.2163]
#   [-0.0141  0.0178 -0.0872  0.4087 -0.2163  0.15  ]]
#
#  [[ 0.1605 -0.0215  0.4213  0.0065  0.0376 -0.0242]
#   [-0.0215  0.0176 -0.0912 -0.1211  0.0196 -0.0082]
#   [ 0.4213 -0.0912  1.4953  0.2075  0.0795 -0.0517]
#   [ 0.0065 -0.1211  0.2075  1.1737 -0.2903  0.1482]
#   [ 0.0376  0.0196  0.0795 -0.2903  0.0932 -0.0516]
#   [-0.0242 -0.0082 -0.0517  0.1482 -0.0516  0.0301]]]
# ECL
# {'CompleteName': 'Eclipsing Variables', 'max_period': 100, 'min_period': 0.1, 'Binary': {'Period': [1, 10], 'teff_val': [5000, 6000], 'FeH_J95': [-0.1, 0.1], 'abs_Gmag': [0.5, 2.0], 'radius_val': [0.8, 1.5], 'logg': [3.5, 4.5], 'Midpoints': {'Period': 5.5, 'teff_val': 5500, 'FeH_J95': 0, 'abs_Gmag': 1.25, 'radius_val': 1.15, 'logg': 4}}, 'Ternary': {'Period': [5, 20], 'teff_val': [4500, 5600], 'FeH_J95': [-0.2, 0.2], 'abs_Gmag': [0.7, 2.5], 'radius_val': [1, 2], 'logg': [3, 4], 'Midpoints': {'Period': 12.5, 'teff_val': 5050, 'FeH_J95': 0, 'abs_Gmag': 1.6, 'radius_val': 1.5, 'logg': 3.5}}, 'Pulsating': {'Period': [0.5, 8], 'teff_val': [5200, 5800], 'FeH_J95': [-0.1, 0.1], 'abs_Gmag': [0.6, 1.8], 'radius_val': [0.9, 1.4], 'logg': [3.8, 4.2], 'Midpoints': {'Period': 4.25, 'teff_val': 5500, 'FeH_J95': 0, 'abs_Gmag': 1.2, 'radius_val': 1.15, 'logg': 4}}}
# [[1.7047 8.6125 0.     1.25   0.1398 4.    ]
#  [2.5257 8.5271 0.     1.6    0.4055 3.5   ]
#  [1.4469 8.6125 0.     1.2    0.1398 4.    ]]
# 3
# <__main__.BayesianGaussianMixtureModel object at 0x7fc29bb01b10>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([1.8925, 8.5841, 0.    , 1.35  , 0.2283, 3.8333]),
#                         n_components=3, random_state=42)
#
# Fitted Means:
# [[ 0.9897  8.8733 -0.5516  1.9766  0.8663  3.8438]
#  [ 1.0076  9.7964 -0.5528 -0.1313  0.7422  4.4324]
#  [ 0.0921  8.5686 -1.2907  5.4049 -0.1056  4.404 ]]
#
# Fitted Covariances:
# [[[ 1.6951 -0.0914  0.1336 -0.2346  0.2946 -0.2522]
#   [-0.0914  0.0559 -0.0472 -0.1638 -0.025   0.0448]
#   [ 0.1336 -0.0472  0.368   0.0919  0.0371 -0.0189]
#   [-0.2346 -0.1638  0.0919  1.9639 -0.6324  0.3607]
#   [ 0.2946 -0.025   0.0371 -0.6324  0.3517 -0.259 ]
#   [-0.2522  0.0448 -0.0189  0.3607 -0.259   0.2083]]
#
#  [[ 0.6953  0.0006  0.0373 -0.0727  0.0302 -0.0186]
#   [ 0.0006  0.0335  0.0154 -0.1574  0.0436 -0.0093]
#   [ 0.0373  0.0154  0.1434 -0.2027  0.075  -0.0343]
#   [-0.0727 -0.1574 -0.2027  0.9029 -0.273   0.0836]
#   [ 0.0302  0.0436  0.075  -0.273   0.0855 -0.0289]
#   [-0.0186 -0.0093 -0.0343  0.0836 -0.0289  0.0126]]
#
#  [[ 1.3195  0.0043  0.0004 -0.2167  0.0927 -0.0545]
#   [ 0.0043  0.0166 -0.0024 -0.1427  0.0272 -0.0102]
#   [ 0.0004 -0.0024  1.2021 -0.2966  0.1287 -0.0468]
#   [-0.2167 -0.1427 -0.2966  1.8334 -0.5074  0.2551]
#   [ 0.0927  0.0272  0.1287 -0.5074  0.1698 -0.0939]
#   [-0.0545 -0.0102 -0.0468  0.2551 -0.0939  0.0596]]]
# ELL
# {'CompleteName': 'Ellipsoidal Variables', 'max_period': 200, 'min_period': 0.2, 'ELL': {'Period': [0.2, 200], 'teff_val': [4000, 5500], 'FeH_J95': [-0.5, 0], 'abs_Gmag': [0.5, 5], 'radius_val': [10, 20], 'logg': [0.5, 1.5], 'Midpoints': {'Period': 100, 'teff_val': 4750, 'FeH_J95': -0.25, 'abs_Gmag': 2.75, 'radius_val': 15, 'logg': 1}}}
# [[ 4.6052  8.4659 -0.25    2.75    2.7081  1.    ]]
# 1
# <__main__.BayesianGaussianMixtureModel object at 0x7fc29bb01510>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([ 4.6052,  8.4659, -0.25  ,  2.75  ,  2.7081,  1.    ]),
#                         random_state=42)
#
# Fitted Means:
# [[ 2.5598  8.5902 -0.4514  2.3374  1.2951  3.4117]]
#
# Fitted Covariances:
# [[[ 4.3465 -0.1108  0.511  -3.0832  1.7163 -1.3162]
#   [-0.1108  0.0627 -0.0163 -0.1378 -0.0515  0.0734]
#   [ 0.511  -0.0163  0.6689 -0.4676  0.2532 -0.1494]
#   [-3.0832 -0.1378 -0.4676  5.6887 -2.4397  1.7196]
#   [ 1.7163 -0.0515  0.2532 -2.4397  1.2693 -0.9681]
#   [-1.3162  0.0734 -0.1494  1.7196 -0.9681  0.7734]]]
# LPV
# {'CompleteName': 'Long-Period Variables', 'max_period': 1000, 'min_period': 100, 'LPV': {'Period': [100.0, 1000.0], 'teff_val': [2000, 3500], 'FeH_J95': [-1, 0], 'abs_Gmag': [-1.5, 2.0], 'radius_val': [100, 200], 'logg': [-0.5, 0.5], 'Midpoints': {'Period': 550, 'teff_val': 2750, 'FeH_J95': -0.5, 'abs_Gmag': 0.25, 'radius_val': 150, 'logg': 0}}}
# [[ 6.3099  7.9194 -0.5     0.25    5.0106  0.    ]]
# 1
# <__main__.BayesianGaussianMixtureModel object at 0x7fc29bb01450>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([ 6.3099,  7.9194, -0.5   ,  0.25  ,  5.0106,  0.    ]),
#                         random_state=42)
#
# Fitted Means:
# [[ 5.6831  8.1951 -0.0274 -2.3107  4.7316  0.5909]]
#
# Fitted Covariances:
# [[[ 0.1071 -0.003   0.0123  0.0333  0.0036 -0.0033]
#   [-0.003   0.0125 -0.0225  0.024  -0.0627  0.0564]
#   [ 0.0123 -0.0225  0.4018 -0.186   0.1994 -0.0078]
#   [ 0.0333  0.024  -0.186   2.5711 -1.1703  0.5848]
#   [ 0.0036 -0.0627  0.1994 -1.1703  0.778  -0.4907]
#   [-0.0033  0.0564 -0.0078  0.5848 -0.4907  0.4298]]]
# RRLYR
# {'CompleteName': 'RR Lyrae Variables', 'max_period': 1.0, 'min_period': 0.2, 'RRab': {'Period': [0.3, 0.9], 'teff_val': [6200, 6800], 'FeH_J95': [-1.0, 0.5], 'abs_Gmag': [0.3, 1.0], 'radius_val': [0.6, 0.8], 'logg': [2.5, 3.5], 'Midpoints': {'Period': 0.6, 'teff_val': 6500, 'FeH_J95': -0.25, 'abs_Gmag': 0.65, 'radius_val': 0.7, 'logg': 3.0}}, 'RRc': {'Period': [0.2, 0.5], 'teff_val': [6400, 7000], 'FeH_J95': [-0.9, 0.4], 'abs_Gmag': [0.4, 1.1], 'radius_val': [0.7, 0.9], 'logg': [2.4, 3.4], 'Midpoints': {'Period': 0.35, 'teff_val': 6700, 'FeH_J95': -0.25, 'abs_Gmag': 0.75, 'radius_val': 0.8, 'logg': 2.9}}, 'RRd': {'Period': [0.74, 0.75], 'teff_val': [6200, 7000], 'FeH_J95': [-1.1, 0.3], 'abs_Gmag': [0.3, 1.0], 'radius_val': [0.65, 0.85], 'logg': [2.6, 3.6], 'Midpoints': {'Period': 0.745, 'teff_val': 6600, 'FeH_J95': -0.4, 'abs_Gmag': 0.65, 'radius_val': 0.75, 'logg': 3.1}}}
# [[-0.5108  8.7796 -0.25    0.65   -0.3567  3.    ]
#  [-1.0498  8.8099 -0.25    0.75   -0.2231  2.9   ]
#  [-0.2944  8.7948 -0.4     0.65   -0.2877  3.1   ]]
# 3
# <__main__.BayesianGaussianMixtureModel object at 0x7fc1f7059c90>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([-0.6183,  8.7947, -0.3   ,  0.6833, -0.2892,  3.    ]),
#                         n_components=3, random_state=42)
#
# Fitted Means:
# [[-0.745   8.3141 -1.7101  7.6592 -0.5088  4.4389]
#  [-0.7578  8.6021 -2.8501  5.6239 -0.2728  4.5069]
#  [-0.8765  8.8856 -0.7801  1.9538  0.8882  3.8222]]
#
# Fitted Covariances:
# [[[ 0.0682 -0.0015  0.0195 -0.0186  0.0128 -0.0098]
#   [-0.0015  0.0067 -0.0575 -0.0578  0.0075 -0.0019]
#   [ 0.0195 -0.0575  1.2416  0.4358 -0.0402  0.0826]
#   [-0.0186 -0.0578  0.4358  0.8447 -0.2209  0.1306]
#   [ 0.0128  0.0075 -0.0402 -0.2209  0.0821 -0.0526]
#   [-0.0098 -0.0019  0.0826  0.1306 -0.0526  0.0584]]
#
#  [[ 0.0933  0.0029  0.0213 -0.0848  0.033  -0.0231]
#   [ 0.0029  0.0091 -0.0432 -0.0738  0.0145 -0.0088]
#   [ 0.0213 -0.0432  1.361   0.1997 -0.0045 -0.0032]
#   [-0.0848 -0.0738  0.1997  1.1005 -0.3476  0.2407]
#   [ 0.033   0.0145 -0.0045 -0.3476  0.1297 -0.0915]
#   [-0.0231 -0.0088 -0.0032  0.2407 -0.0915  0.0669]]
#
#  [[ 0.1208 -0.0265  0.0491 -0.0109  0.055  -0.0508]
#   [-0.0265  0.0922 -0.1319 -0.0158 -0.165   0.1563]
#   [ 0.0491 -0.1319  0.8381  0.0478  0.2229 -0.1594]
#   [-0.0109 -0.0158  0.0478  1.7881 -0.8565  0.6307]
#   [ 0.055  -0.165   0.2229 -0.8565  0.749  -0.6124]
#   [-0.0508  0.1563 -0.1594  0.6307 -0.6124  0.5233]]]
# T2CEP
# {'CompleteName': 'Type II Cepheids', 'max_period': 150, 'min_period': 1, 'BL Herculis': {'Period': [1, 4], 'teff_val': [5500, 7000], 'FeH_J95': [-0.5, 0.3], 'abs_Gmag': [0.7, 1.5], 'radius_val': [5, 10], 'logg': [1.0, 2.0], 'Midpoints': {'Period': 2.5, 'teff_val': 6250, 'FeH_J95': -0.1, 'abs_Gmag': 1.1, 'radius_val': 7.5, 'logg': 1.5}}, 'W Virginis': {'Period': [10, 20], 'teff_val': [4500, 6000], 'FeH_J95': [-0.7, 0.1], 'abs_Gmag': [0.5, 1.2], 'radius_val': [15, 25], 'logg': [0.5, 1.5], 'Midpoints': {'Period': 15, 'teff_val': 5250, 'FeH_J95': -0.3, 'abs_Gmag': 0.85, 'radius_val': 20, 'logg': 1.0}}, 'RV Tauri': {'Period': [30, 150], 'teff_val': [4500, 6500], 'FeH_J95': [-0.8, 0], 'abs_Gmag': [0.3, 1.4], 'radius_val': [30, 40], 'logg': [0.2, 0.8], 'Midpoints': {'Period': 90, 'teff_val': 5500, 'FeH_J95': -0.4, 'abs_Gmag': 0.85, 'radius_val': 35, 'logg': 0.5}}}
# [[ 0.9163  8.7403 -0.1     1.1     2.0149  1.5   ]
#  [ 2.7081  8.566  -0.3     0.85    2.9957  1.    ]
#  [ 4.4998  8.6125 -0.4     0.85    3.5553  0.5   ]]
# 3
# <__main__.BayesianGaussianMixtureModel object at 0x7fc1f7059d10>
# Hyperparameters:
# BayesianGaussianMixture(max_iter=5000,
#                         mean_prior=array([ 2.7081,  8.6396, -0.2667,  0.9333,  2.8553,  1.    ]),
#                         n_components=3, random_state=42)
#
# Fitted Means:
# [[ 2.5553  8.9402 -0.552  -0.2848  1.9218  3.0952]
#  [ 2.1862  8.6046 -0.4832  1.7672  1.4907  3.2727]
#  [ 1.3053  8.6096 -1.7827  5.3581 -0.1632  4.4677]]
#
# Fitted Covariances:
# [[[ 1.5388 -0.1308  0.1517 -0.9034  0.7056 -0.55  ]
#   [-0.1308  0.1854 -0.0124 -0.0455 -0.3006  0.3234]
#   [ 0.1517 -0.0124  0.4941 -0.3123  0.215  -0.1048]
#   [-0.9034 -0.0455 -0.3123  1.7175 -0.7887  0.4416]
#   [ 0.7056 -0.3006  0.215  -0.7887  0.9446 -0.8088]
#   [-0.55    0.3234 -0.1048  0.4416 -0.8088  0.7575]]
#
#  [[ 1.0613 -0.0069  0.2321 -0.633   0.3058 -0.1779]
#   [-0.0069  0.0163 -0.0504  0.013  -0.042   0.0372]
#   [ 0.2321 -0.0504  0.797  -0.232   0.2157 -0.1246]
#   [-0.633   0.013  -0.232   1.9987 -0.9589  0.6122]
#   [ 0.3058 -0.042   0.2157 -0.9589  0.5405 -0.3698]
#   [-0.1779  0.0372 -0.1246  0.6122 -0.3698  0.2667]]
#
#  [[ 0.849  -0.0127  0.3676 -0.2645  0.1362 -0.0843]
#   [-0.0127  0.0198 -0.0611 -0.0926 -0.0018  0.0088]
#   [ 0.3676 -0.0611  1.6889 -0.1299  0.184  -0.1185]
#   [-0.2645 -0.0926 -0.1299  0.9921 -0.2531  0.1297]
#   [ 0.1362 -0.0018  0.184  -0.2531  0.1249 -0.0851]
#   [-0.0843  0.0088 -0.1185  0.1297 -0.0851  0.0659]]]
